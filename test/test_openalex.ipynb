# %% [markdown]
# ## Notebook to test OpenAlex
# #### An open and comprehensive catalog of scholarly papers, authors, and institutions.

# %%
# install necessary packages
# !pip install pyalex
# Out:
# Requirement already satisfied: pyalex in /Users/andrewehsaei/.pyenv/versions/3.9.16/lib/python3.9/site-packages (0.10.1)
# Requirement already satisfied: requests in /Users/andrewehsaei/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from pyalex) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/andrewehsaei/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->pyalex) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/andrewehsaei/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->pyalex) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/andrewehsaei/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->pyalex) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andrewehsaei/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->pyalex) (2022.12.7)

# %%
# import packages
from pyalex import Works, Authors, Sources, Institutions, Concepts, Publishers, Funders
import polars as pl

# %%
# Set the config widths to show more text in dataframes
pl.Config.set_ascii_tables()
pl.Config.set_tbl_width_chars(128)
pl.Config.set_fmt_str_lengths(64)
# Out:
# polars.config.Config

# %%
# grab random sources from open-alex
Sources().random()
# Out:
# {'id': 'https://openalex.org/S63040059',
#  'issn_l': '1551-7144',
#  'issn': ['1551-7144', '1559-2030'],
#  'display_name': 'Contemporary Clinical Trials',
#  'host_organization': 'https://openalex.org/P4310320990',
#  'host_organization_name': 'Elsevier BV',
#  'host_organization_lineage': ['https://openalex.org/P4310320990'],
#  'works_count': 3116,
#  'cited_by_count': 50118,
#  'summary_stats': {'2yr_mean_citedness': 2.2018518518518517,
#   'h_index': 77,
#   'i10_index': 1338},
#  'is_oa': False,
#  'is_in_doaj': False,
#  'ids': {'openalex': 'https://openalex.org/S63040059',
#   'issn_l': '1551-7144',
#   'issn': ['1551-7144', '1559-2030'],
#   'mag': '63040059',
#   'wikidata': 'https://www.wikidata.org/entity/Q5164971'},
#  'homepage_url': 'https://www.journals.elsevier.com/contemporary-clinical-trials',
#  'apc_prices': None,
#  'apc_usd': None,
#  'country_code': 'US',
#  'societies': [],
#  'alternate_titles': ['Contemp clin trials 4'],
#  'abbreviated_title': None,
#  'type': 'journal',
#  'x_concepts': [{'id': 'https://openalex.org/C71924100',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#    'display_name': 'Medicine',
#    'level': 0,
#    'score': 101.6},
#   {'id': 'https://openalex.org/C126322002',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#    'display_name': 'Internal medicine',
#    'level': 1,
#    'score': 88.5},
#   {'id': 'https://openalex.org/C142724271',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7208',
#    'display_name': 'Pathology',
#    'level': 1,
#    'score': 87.2},
#   {'id': 'https://openalex.org/C86803240',
#    'wikidata': 'https://www.wikidata.org/wiki/Q420',
#    'display_name': 'Biology',
#    'level': 0,
#    'score': 79.1},
#   {'id': 'https://openalex.org/C141071460',
#    'wikidata': 'https://www.wikidata.org/wiki/Q40821',
#    'display_name': 'Surgery',
#    'level': 1,
#    'score': 70.0},
#   {'id': 'https://openalex.org/C168563851',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1436668',
#    'display_name': 'Randomized controlled trial',
#    'level': 2,
#    'score': 64.8},
#   {'id': 'https://openalex.org/C15744967',
#    'wikidata': 'https://www.wikidata.org/wiki/Q9418',
#    'display_name': 'Psychology',
#    'level': 0,
#    'score': 61.2},
#   {'id': 'https://openalex.org/C118552586',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7867',
#    'display_name': 'Psychiatry',
#    'level': 1,
#    'score': 55.4},
#   {'id': 'https://openalex.org/C159110408',
#    'wikidata': 'https://www.wikidata.org/wiki/Q121176',
#    'display_name': 'Nursing',
#    'level': 1,
#    'score': 45.4},
#   {'id': 'https://openalex.org/C60644358',
#    'wikidata': 'https://www.wikidata.org/wiki/Q128570',
#    'display_name': 'Bioinformatics',
#    'level': 1,
#    'score': 41.7},
#   {'id': 'https://openalex.org/C535046627',
#    'wikidata': 'https://www.wikidata.org/wiki/Q30612',
#    'display_name': 'Clinical trial',
#    'level': 2,
#    'score': 40.9},
#   {'id': 'https://openalex.org/C17744445',
#    'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#    'display_name': 'Political science',
#    'level': 0,
#    'score': 35.6},
#   {'id': 'https://openalex.org/C199539241',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#    'display_name': 'Law',
#    'level': 1,
#    'score': 35.2},
#   {'id': 'https://openalex.org/C162324750',
#    'wikidata': 'https://www.wikidata.org/wiki/Q8134',
#    'display_name': 'Economics',
#    'level': 0,
#    'score': 33.6},
#   {'id': 'https://openalex.org/C512399662',
#    'wikidata': 'https://www.wikidata.org/wiki/Q3505712',
#    'display_name': 'Family medicine',
#    'level': 1,
#    'score': 32.4},
#   {'id': 'https://openalex.org/C1862650',
#    'wikidata': 'https://www.wikidata.org/wiki/Q186005',
#    'display_name': 'Physical therapy',
#    'level': 1,
#    'score': 32.3},
#   {'id': 'https://openalex.org/C144024400',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21201',
#    'display_name': 'Sociology',
#    'level': 0,
#    'score': 30.6},
#   {'id': 'https://openalex.org/C33923547',
#    'wikidata': 'https://www.wikidata.org/wiki/Q395',
#    'display_name': 'Mathematics',
#    'level': 0,
#    'score': 29.6},
#   {'id': 'https://openalex.org/C2780665704',
#    'wikidata': 'https://www.wikidata.org/wiki/Q959298',
#    'display_name': 'Intervention (counseling)',
#    'level': 2,
#    'score': 29.5},
#   {'id': 'https://openalex.org/C105795698',
#    'wikidata': 'https://www.wikidata.org/wiki/Q12483',
#    'display_name': 'Statistics',
#    'level': 1,
#    'score': 27.5},
#   {'id': 'https://openalex.org/C204787440',
#    'wikidata': 'https://www.wikidata.org/wiki/Q188504',
#    'display_name': 'Alternative medicine',
#    'level': 2,
#    'score': 26.4},
#   {'id': 'https://openalex.org/C27415008',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7256382',
#    'display_name': 'Psychological intervention',
#    'level': 2,
#    'score': 25.0},
#   {'id': 'https://openalex.org/C134018914',
#    'wikidata': 'https://www.wikidata.org/wiki/Q162606',
#    'display_name': 'Endocrinology',
#    'level': 1,
#    'score': 24.3},
#   {'id': 'https://openalex.org/C41008148',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#    'display_name': 'Computer science',
#    'level': 0,
#    'score': 23.7},
#   {'id': 'https://openalex.org/C542102704',
#    'wikidata': 'https://www.wikidata.org/wiki/Q183257',
#    'display_name': 'Psychotherapist',
#    'level': 1,
#    'score': 21.0}],
#  'counts_by_year': [{'year': 2023, 'works_count': 203, 'cited_by_count': 2974},
#   {'year': 2022, 'works_count': 288, 'cited_by_count': 6106},
#   {'year': 2021, 'works_count': 313, 'cited_by_count': 5994},
#   {'year': 2020, 'works_count': 227, 'cited_by_count': 5316},
#   {'year': 2019, 'works_count': 172, 'cited_by_count': 4636},
#   {'year': 2018, 'works_count': 221, 'cited_by_count': 4205},
#   {'year': 2017, 'works_count': 180, 'cited_by_count': 3814},
#   {'year': 2016, 'works_count': 167, 'cited_by_count': 3324},
#   {'year': 2015, 'works_count': 227, 'cited_by_count': 2935},
#   {'year': 2014, 'works_count': 131, 'cited_by_count': 2614},
#   {'year': 2013, 'works_count': 163, 'cited_by_count': 2115},
#   {'year': 2012, 'works_count': 177, 'cited_by_count': 1638}],
#  'works_api_url': 'https://api.openalex.org/works?filter=primary_location.source.id:S63040059',
#  'updated_date': '2023-06-21',
#  'created_date': '2016-06-24'}

# %%
# Filter works on the current year
works = pl.DataFrame(Works().filter(publication_year=2023).select(["id", "title", "display_name", "publication_date","id","doi"]).get())

# Sort the works by publish data
works.sort(by="publication_date", descending=True)
# Out:
# shape: (25, 5)
# +--------------------------+--------------------------+--------------------------+------------------+--------------------------+
# | id                       | title                    | display_name             | publication_date | doi                      |
# | ---                      | ---                      | ---                      | ---              | ---                      |
# | str                      | str                      | str                      | str              | str                      |
# +==============================================================================================================================+
# | https://openalex.org/W42 | Dematiaceous             | Dematiaceous             | 2023-07-01       | https://doi.org/10.1079/ |
# | 91783855                 | Hyphomycetes             | Hyphomycetes             |                  | 9780851986180.0000       |
# | https://openalex.org/W43 | Journal of Lightwave     | Journal of Lightwave     | 2023-06-19       | https://doi.org/10.1109/ |
# | 62597599                 | Technology               | Technology               |                  | jlt.50                   |
# | https://openalex.org/W42 | IEEE Journal of Selected | IEEE Journal of Selected | 2023-06-13       | https://doi.org/10.1109/ |
# | 12930147                 | Topics in Quantum        | Topics in Quantum        |                  | jstqe.2944               |
# |                          | Electronics              | Electronics              |                  |                          |
# | https://openalex.org/W20 | Flatland: A Romance of   | Flatland: A Romance of   | 2023-05-23       | https://doi.org/10.4324/ |
# | 81899208                 | Many Dimensions          | Many Dimensions          |                  | 9781003056355-4          |
# | ...                      | ...                      | ...                      | ...              | ...                      |
# | https://openalex.org/W43 | Cancer statistics, 2023  | Cancer statistics, 2023  | 2023-01-01       | https://doi.org/10.3322/ |
# | 15754639                 |                          |                          |                  | caac.21763               |
# | https://openalex.org/W65 | Economic Freedom of the  | Economic Freedom of the  | 2023-01-01       | https://doi.org/10.2139/ |
# | 5022340                  | World: 2022 Annual       | World: 2022 Annual       |                  | ssrn.4327127             |
# |                          | Report                   | Report                   |                  |                          |
# | https://openalex.org/W27 | Foundations of mixed     | Foundations of mixed     | 2023-01-01       | https://doi.org/10.1016/ |
# | 37006899                 | methods research         | methods research         |                  | b978-0-12-818630-5.11036 |
# |                          |                          |                          |                  | -x                       |
# | https://openalex.org/W42 | A Survey on Vision       | A Survey on Vision       | 2023-01-01       | https://doi.org/10.1109/ |
# | 13019189                 | Transformer              | Transformer              |                  | tpami.2022.3152247       |
# +--------------------------+--------------------------+--------------------------+------------------+--------------------------+

# %%
# Get a list of publishers
pubs = Publishers().get()

def extract_item(list_of_dicts, key):
    items = []
    for dictionary in list_of_dicts:
        if key in dictionary:
            items.append(dictionary[key])
    return items

result = extract_item(pubs, 'display_name')
print(result)
# Out:
# ['Elsevier BV', 'Springer Nature', 'Wiley', 'Springer Science+Business Media', 'Wiley-Blackwell', 'Taylor & Francis', 'University of Oxford', 'Oxford University Press', 'SAGE Publishing', 'Wolters Kluwer', 'Lippincott Williams & Wilkins', 'University of Cambridge', 'Cambridge University Press', 'American Chemical Society', 'Institute of Electrical and Electronics Engineers', 'Nature Portfolio', 'Institute of Physics', 'IOP Publishing', 'MDPI', 'BMJ', 'American Institute of Physics', 'De Gruyter', 'Thieme Medical Publishers (Germany)', 'Royal Society of Chemistry', 'American Physical Society']

# %%
Works()["W4313531093"]
# Out:
# {'id': 'https://openalex.org/W4313531093',
#  'doi': 'https://doi.org/10.1016/j.cell.2022.11.001',
#  'title': 'Hallmarks of aging: An expanding universe',
#  'display_name': 'Hallmarks of aging: An expanding universe',
#  'publication_year': 2023,
#  'publication_date': '2023-01-01',
#  'ids': {'openalex': 'https://openalex.org/W4313531093',
#   'doi': 'https://doi.org/10.1016/j.cell.2022.11.001',
#   'pmid': 'https://pubmed.ncbi.nlm.nih.gov/36599349'},
#  'language': 'en',
#  'primary_location': {'is_oa': False,
#   'landing_page_url': 'https://doi.org/10.1016/j.cell.2022.11.001',
#   'pdf_url': None,
#   'source': {'id': 'https://openalex.org/S110447773',
#    'display_name': 'Cell',
#    'issn_l': '0092-8674',
#    'issn': ['0092-8674', '1097-4172'],
#    'is_oa': False,
#    'is_in_doaj': False,
#    'host_organization': 'https://openalex.org/P4310315673',
#    'host_organization_name': 'Cell Press',
#    'host_organization_lineage': ['https://openalex.org/P4310320990',
#     'https://openalex.org/P4310315673'],
#    'host_organization_lineage_names': ['Elsevier BV', 'Cell Press'],
#    'type': 'journal'},
#   'license': None,
#   'version': None},
#  'type': 'journal-article',
#  'open_access': {'is_oa': False,
#   'oa_status': 'closed',
#   'oa_url': None,
#   'any_repository_has_fulltext': False},
#  'authorships': [{'author_position': 'first',
#    'author': {'id': 'https://openalex.org/A4357475601',
#     'display_name': 'Carlos López-Otín',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I4210158561',
#      'display_name': 'Centro de Investigación Biomédica en Red de Cáncer',
#      'ror': 'https://ror.org/04hya7017',
#      'country_code': 'ES',
#      'type': 'facility'},
#     {'id': 'https://openalex.org/I4210166274',
#      'display_name': 'Instituto de Investigación Sanitaria del Principado de Asturias',
#      'ror': 'https://ror.org/05xzb7x97',
#      'country_code': 'ES',
#      'type': 'facility'},
#     {'id': 'https://openalex.org/I165339363',
#      'display_name': 'University of Oviedo',
#      'ror': 'https://ror.org/006gksa02',
#      'country_code': 'ES',
#      'type': 'education'}],
#    'is_corresponding': True,
#    'raw_affiliation_string': 'Departamento de Bioquímica y Biología Molecular, Instituto Universitario de Oncología (IUOPA), Universidad de Oviedo, Oviedo, Spain; Instituto de Investigación Sanitaria del Principado de Asturias (ISPA), Oviedo, Spain; Centro de Investigación Biomédica en Red de Cáncer (CIBERONC), Madrid, Spain. Electronic address: clo@uniovi.es.',
#    'raw_affiliation_strings': ['Departamento de Bioquímica y Biología Molecular, Instituto Universitario de Oncología (IUOPA), Universidad de Oviedo, Oviedo, Spain; Instituto de Investigación Sanitaria del Principado de Asturias (ISPA), Oviedo, Spain; Centro de Investigación Biomédica en Red de Cáncer (CIBERONC), Madrid, Spain. Electronic address: clo@uniovi.es.']},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A4316325822',
#     'display_name': 'Maria A Blasco',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I4210089594',
#      'display_name': 'Spanish National Cancer Research Centre',
#      'ror': 'https://ror.org/00bvhmc43',
#      'country_code': 'ES',
#      'type': 'facility'}],
#    'is_corresponding': False,
#    'raw_affiliation_string': 'Telomeres and Telomerase Group, Molecular Oncology Program, Spanish National Cancer Centre (CNIO), Madrid, Spain.',
#    'raw_affiliation_strings': ['Telomeres and Telomerase Group, Molecular Oncology Program, Spanish National Cancer Centre (CNIO), Madrid, Spain.']},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A4316325823',
#     'display_name': 'Linda Partridge',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I4210153965',
#      'display_name': 'Max Planck Institute for Biology of Ageing',
#      'ror': 'https://ror.org/04xx1tc24',
#      'country_code': 'DE',
#      'type': 'nonprofit'},
#     {'id': 'https://openalex.org/I45129253',
#      'display_name': 'University College London',
#      'ror': 'https://ror.org/02jx3x895',
#      'country_code': 'GB',
#      'type': 'education'}],
#    'is_corresponding': False,
#    'raw_affiliation_string': 'Department of Genetics, Evolution and Environment, Institute of Healthy Ageing, University College London, London, UK; Max Planck Institute for Biology of Ageing, Cologne, Germany.',
#    'raw_affiliation_strings': ['Department of Genetics, Evolution and Environment, Institute of Healthy Ageing, University College London, London, UK; Max Planck Institute for Biology of Ageing, Cologne, Germany.']},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A4316325824',
#     'display_name': 'Manuel Serrano',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I11932220',
#      'display_name': 'Institució Catalana de Recerca i Estudis Avançats',
#      'ror': 'https://ror.org/0371hy230',
#      'country_code': 'ES',
#      'type': 'nonprofit'},
#     {'id': 'https://openalex.org/I4210122345',
#      'display_name': 'Institute for Research in Biomedicine',
#      'ror': 'https://ror.org/01z1gye03',
#      'country_code': 'ES',
#      'type': 'healthcare'}],
#    'is_corresponding': False,
#    'raw_affiliation_string': 'Institute for Research in Biomedicine (IRB Barcelona), Barcelona Institute of Science and Technology (BIST), Barcelona, Spain; Catalan Institution for Research and Advanced Studies (ICREA), Barcelona, Spain; Altos Labs, Cambridge, UK.',
#    'raw_affiliation_strings': ['Institute for Research in Biomedicine (IRB Barcelona), Barcelona Institute of Science and Technology (BIST), Barcelona, Spain; Catalan Institution for Research and Advanced Studies (ICREA), Barcelona, Spain; Altos Labs, Cambridge, UK.']},
#   {'author_position': 'last',
#    'author': {'id': 'https://openalex.org/A4359393056',
#     'display_name': 'Guido Kroemer',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I204730241',
#      'display_name': 'Université Paris Cité',
#      'ror': 'https://ror.org/05f82e368',
#      'country_code': 'FR',
#      'type': 'education'},
#     {'id': 'https://openalex.org/I154526488',
#      'display_name': 'Inserm',
#      'ror': 'https://ror.org/02vjkv261',
#      'country_code': 'FR',
#      'type': 'government'},
#     {'id': 'https://openalex.org/I4210092322',
#      'display_name': 'Centre de Recherche des Cordeliers',
#      'ror': 'https://ror.org/00dmms154',
#      'country_code': 'FR',
#      'type': 'facility'},
#     {'id': 'https://openalex.org/I4210102325',
#      'display_name': 'Hôpital Européen Georges-Pompidou',
#      'ror': 'https://ror.org/016vx5156',
#      'country_code': 'FR',
#      'type': 'healthcare'},
#     {'id': 'https://openalex.org/I185839726',
#      'display_name': 'Institut Universitaire de France',
#      'ror': 'https://ror.org/055khg266',
#      'country_code': 'FR',
#      'type': 'education'}],
#    'is_corresponding': False,
#    'raw_affiliation_string': 'Centre de Recherche des Cordeliers, Equipe labellisée par la Ligue contre le cancer, Université de Paris, Sorbonne Université, INSERM U1138, Institut Universitaire de France, Paris, France; Metabolomics and Cell Biology Platforms, Gustave Roussy, Villejuif, France; Institut du Cancer Paris CARPEM, Department of Biology, Hôpital Européen Georges Pompidou, AP-HP, Paris, France. Electronic address: kroemer@orange.fr.',
#    'raw_affiliation_strings': ['Centre de Recherche des Cordeliers, Equipe labellisée par la Ligue contre le cancer, Université de Paris, Sorbonne Université, INSERM U1138, Institut Universitaire de France, Paris, France; Metabolomics and Cell Biology Platforms, Gustave Roussy, Villejuif, France; Institut du Cancer Paris CARPEM, Department of Biology, Hôpital Européen Georges Pompidou, AP-HP, Paris, France. Electronic address: kroemer@orange.fr.']}],
#  'corresponding_author_ids': ['https://openalex.org/A4357475601'],
#  'corresponding_institution_ids': ['https://openalex.org/I4210158561',
#   'https://openalex.org/I4210166274',
#   'https://openalex.org/I165339363'],
#  'apc_list': None,
#  'apc_paid': None,
#  'cited_by_count': 150,
#  'biblio': {'volume': '186',
#   'issue': '2',
#   'first_page': '243',
#   'last_page': '278'},
#  'is_retracted': False,
#  'is_paratext': False,
#  'concepts': [{'id': 'https://openalex.org/C86803240',
#    'wikidata': 'https://www.wikidata.org/wiki/Q420',
#    'display_name': 'Biology',
#    'level': 0,
#    'score': 0.8658726},
#   {'id': 'https://openalex.org/C2781452922',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2892805',
#    'display_name': 'Proteostasis',
#    'level': 2,
#    'score': 0.8076911},
#   {'id': 'https://openalex.org/C177336024',
#    'wikidata': 'https://www.wikidata.org/wiki/Q14872779',
#    'display_name': 'Telomere',
#    'level': 3,
#    'score': 0.75429016},
#   {'id': 'https://openalex.org/C41091548',
#    'wikidata': 'https://www.wikidata.org/wiki/Q26939',
#    'display_name': 'Epigenetics',
#    'level': 3,
#    'score': 0.67259383},
#   {'id': 'https://openalex.org/C178169997',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2892636',
#    'display_name': 'Genome instability',
#    'level': 4,
#    'score': 0.66543984},
#   {'id': 'https://openalex.org/C522857546',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2070979',
#    'display_name': 'Senescence',
#    'level': 2,
#    'score': 0.62479246},
#   {'id': 'https://openalex.org/C110455231',
#    'wikidata': 'https://www.wikidata.org/wiki/Q897788',
#    'display_name': 'Compartmentalization (fire protection)',
#    'level': 3,
#    'score': 0.5133378},
#   {'id': 'https://openalex.org/C94581717',
#    'wikidata': 'https://www.wikidata.org/wiki/Q331839',
#    'display_name': 'Telomerase',
#    'level': 3,
#    'score': 0.50986356},
#   {'id': 'https://openalex.org/C2776914184',
#    'wikidata': 'https://www.wikidata.org/wiki/Q101991',
#    'display_name': 'Inflammation',
#    'level': 2,
#    'score': 0.46987158},
#   {'id': 'https://openalex.org/C2779523775',
#    'wikidata': 'https://www.wikidata.org/wiki/Q9075999',
#    'display_name': 'Cellular senescence',
#    'level': 4,
#    'score': 0.44754046},
#   {'id': 'https://openalex.org/C2776759703',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1066907',
#    'display_name': 'Longevity',
#    'level': 2,
#    'score': 0.43841982},
#   {'id': 'https://openalex.org/C2778175527',
#    'wikidata': 'https://www.wikidata.org/wiki/Q332154',
#    'display_name': 'Successful aging',
#    'level': 2,
#    'score': 0.43149927},
#   {'id': 'https://openalex.org/C203522944',
#    'wikidata': 'https://www.wikidata.org/wiki/Q288322',
#    'display_name': 'Autophagy',
#    'level': 3,
#    'score': 0.4214458},
#   {'id': 'https://openalex.org/C2909947164',
#    'wikidata': 'https://www.wikidata.org/wiki/Q6139748',
#    'display_name': 'Premature aging',
#    'level': 2,
#    'score': 0.4109255},
#   {'id': 'https://openalex.org/C169760540',
#    'wikidata': 'https://www.wikidata.org/wiki/Q207011',
#    'display_name': 'Neuroscience',
#    'level': 1,
#    'score': 0.36954346},
#   {'id': 'https://openalex.org/C95444343',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7141',
#    'display_name': 'Cell biology',
#    'level': 1,
#    'score': 0.3311656},
#   {'id': 'https://openalex.org/C54355233',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#    'display_name': 'Genetics',
#    'level': 1,
#    'score': 0.2864483},
#   {'id': 'https://openalex.org/C203014093',
#    'wikidata': 'https://www.wikidata.org/wiki/Q101929',
#    'display_name': 'Immunology',
#    'level': 1,
#    'score': 0.2479901},
#   {'id': 'https://openalex.org/C143425029',
#    'wikidata': 'https://www.wikidata.org/wiki/Q5205747',
#    'display_name': 'DNA damage',
#    'level': 3,
#    'score': 0.21657538},
#   {'id': 'https://openalex.org/C74909509',
#    'wikidata': 'https://www.wikidata.org/wiki/Q10387',
#    'display_name': 'Gerontology',
#    'level': 1,
#    'score': 0.20072621},
#   {'id': 'https://openalex.org/C190283241',
#    'wikidata': 'https://www.wikidata.org/wiki/Q14599311',
#    'display_name': 'Apoptosis',
#    'level': 2,
#    'score': 0.103821516},
#   {'id': 'https://openalex.org/C552990157',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7430',
#    'display_name': 'DNA',
#    'level': 2,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C55493867',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#    'display_name': 'Biochemistry',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C127716648',
#    'wikidata': 'https://www.wikidata.org/wiki/Q104053',
#    'display_name': 'Phenotype',
#    'level': 3,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C104317684',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7187',
#    'display_name': 'Gene',
#    'level': 2,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C181199279',
#    'wikidata': 'https://www.wikidata.org/wiki/Q8047',
#    'display_name': 'Enzyme',
#    'level': 2,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C71924100',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#    'display_name': 'Medicine',
#    'level': 0,
#    'score': 0.0}],
#  'mesh': [{'descriptor_ui': 'D000375',
#    'descriptor_name': 'Aging',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': True},
#   {'descriptor_ui': 'D000375',
#    'descriptor_name': 'Aging',
#    'qualifier_ui': 'Q000473',
#    'qualifier_name': 'pathology',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D000375',
#    'descriptor_name': 'Aging',
#    'qualifier_ui': 'Q000235',
#    'qualifier_name': 'genetics',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D016922',
#    'descriptor_name': 'Cellular Senescence',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D044127',
#    'descriptor_name': 'Epigenesis, Genetic',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D000074702',
#    'descriptor_name': 'Proteostasis',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D013234',
#    'descriptor_name': 'Stem Cells',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False}],
#  'locations_count': 2,
#  'locations': [{'is_oa': False,
#    'landing_page_url': 'https://doi.org/10.1016/j.cell.2022.11.001',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S110447773',
#     'display_name': 'Cell',
#     'issn_l': '0092-8674',
#     'issn': ['0092-8674', '1097-4172'],
#     'is_oa': False,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/P4310315673',
#     'host_organization_name': 'Cell Press',
#     'host_organization_lineage': ['https://openalex.org/P4310320990',
#      'https://openalex.org/P4310315673'],
#     'host_organization_lineage_names': ['Elsevier BV', 'Cell Press'],
#     'type': 'journal'},
#    'license': None,
#    'version': None},
#   {'is_oa': False,
#    'landing_page_url': 'https://pubmed.ncbi.nlm.nih.gov/36599349',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306525036',
#     'display_name': 'PubMed',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': False,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I1299303238',
#     'host_organization_name': 'National Institutes of Health',
#     'host_organization_lineage': ['https://openalex.org/I1299303238'],
#     'host_organization_lineage_names': ['National Institutes of Health'],
#     'type': 'repository'},
#    'license': None,
#    'version': None}],
#  'best_oa_location': None,
#  'grants': [],
#  'referenced_works_count': 294,
#  'referenced_works': ['https://openalex.org/W1531194255',
#   'https://openalex.org/W1553155385',
#   'https://openalex.org/W1832678746',
#   'https://openalex.org/W1852538637',
#   'https://openalex.org/W1891854262',
#   'https://openalex.org/W1969905245',
#   'https://openalex.org/W1974047233',
#   'https://openalex.org/W1992900610',
#   'https://openalex.org/W2004173334',
#   'https://openalex.org/W2006070103',
#   'https://openalex.org/W2006840724',
#   'https://openalex.org/W2008124325',
#   'https://openalex.org/W2009602165',
#   'https://openalex.org/W2018182154',
#   'https://openalex.org/W2021264577',
#   'https://openalex.org/W2037146644',
#   'https://openalex.org/W2039920681',
#   'https://openalex.org/W2042716686',
#   'https://openalex.org/W2053352181',
#   'https://openalex.org/W2076047032',
#   'https://openalex.org/W2081262717',
#   'https://openalex.org/W2082773128',
#   'https://openalex.org/W2092476887',
#   'https://openalex.org/W2095048801',
#   'https://openalex.org/W2097799342',
#   'https://openalex.org/W2099348677',
#   'https://openalex.org/W2105298120',
#   'https://openalex.org/W2110720693',
#   'https://openalex.org/W2125987139',
#   'https://openalex.org/W2126525177',
#   'https://openalex.org/W2128807350',
#   'https://openalex.org/W2130682212',
#   'https://openalex.org/W2132967521',
#   'https://openalex.org/W2146464433',
#   'https://openalex.org/W2160766576',
#   'https://openalex.org/W2169621456',
#   'https://openalex.org/W2210634983',
#   'https://openalex.org/W2266290735',
#   'https://openalex.org/W2270421926',
#   'https://openalex.org/W2279382765',
#   'https://openalex.org/W2290642869',
#   'https://openalex.org/W2337055863',
#   'https://openalex.org/W2371807656',
#   'https://openalex.org/W2418867659',
#   'https://openalex.org/W2421296032',
#   'https://openalex.org/W2473146109',
#   'https://openalex.org/W2515158101',
#   'https://openalex.org/W2524881570',
#   'https://openalex.org/W2537891041',
#   'https://openalex.org/W2542468576',
#   'https://openalex.org/W2550166770',
#   'https://openalex.org/W2553534905',
#   'https://openalex.org/W2554740475',
#   'https://openalex.org/W2565424224',
#   'https://openalex.org/W2577597748',
#   'https://openalex.org/W2594228238',
#   'https://openalex.org/W2606478035',
#   'https://openalex.org/W2613309479',
#   'https://openalex.org/W2628145035',
#   'https://openalex.org/W2687861173',
#   'https://openalex.org/W2750254726',
#   'https://openalex.org/W2765279273',
#   'https://openalex.org/W2768413599',
#   'https://openalex.org/W2784734859',
#   'https://openalex.org/W2786417636',
#   'https://openalex.org/W2790191085',
#   'https://openalex.org/W2795906582',
#   'https://openalex.org/W2796559433',
#   'https://openalex.org/W2797068438',
#   'https://openalex.org/W2802744456',
#   'https://openalex.org/W2804034337',
#   'https://openalex.org/W2804257223',
#   'https://openalex.org/W2844364183',
#   'https://openalex.org/W2860743873',
#   'https://openalex.org/W2889628650',
#   'https://openalex.org/W2891906292',
#   'https://openalex.org/W2892288854',
#   'https://openalex.org/W2893617001',
#   'https://openalex.org/W2897064819',
#   'https://openalex.org/W2901963713',
#   'https://openalex.org/W2902944709',
#   'https://openalex.org/W2906721882',
#   'https://openalex.org/W2909477364',
#   'https://openalex.org/W2911642321',
#   'https://openalex.org/W2913758618',
#   'https://openalex.org/W2913940235',
#   'https://openalex.org/W2914251418',
#   'https://openalex.org/W2921681769',
#   'https://openalex.org/W2922624791',
#   'https://openalex.org/W2924222341',
#   'https://openalex.org/W2937386865',
#   'https://openalex.org/W2946216728',
#   'https://openalex.org/W2948768639',
#   'https://openalex.org/W2951686954',
#   'https://openalex.org/W2954124338',
#   'https://openalex.org/W2954445592',
#   'https://openalex.org/W2956552698',
#   'https://openalex.org/W2962898654',
#   'https://openalex.org/W2963531283',
#   'https://openalex.org/W2967801303',
#   'https://openalex.org/W2968420254',
#   'https://openalex.org/W2969883164',
#   'https://openalex.org/W2970160838',
#   'https://openalex.org/W2970686316',
#   'https://openalex.org/W2971067538',
#   'https://openalex.org/W2972011940',
#   'https://openalex.org/W2974643180',
#   'https://openalex.org/W2976009347',
#   'https://openalex.org/W2977268656',
#   'https://openalex.org/W2977336849',
#   'https://openalex.org/W2977961280',
#   'https://openalex.org/W2980426471',
#   'https://openalex.org/W2981170486',
#   'https://openalex.org/W2981220896',
#   'https://openalex.org/W2985098178',
#   'https://openalex.org/W2987425466',
#   'https://openalex.org/W2988310131',
#   'https://openalex.org/W2989003799',
#   'https://openalex.org/W2989807664',
#   'https://openalex.org/W2991550561',
#   'https://openalex.org/W2993497584',
#   'https://openalex.org/W2996588976',
#   'https://openalex.org/W2999421965',
#   'https://openalex.org/W3000127343',
#   'https://openalex.org/W3000157665',
#   'https://openalex.org/W3008445071',
#   'https://openalex.org/W3009488502',
#   'https://openalex.org/W3011436618',
#   'https://openalex.org/W3013543222',
#   'https://openalex.org/W3015992241',
#   'https://openalex.org/W3017377629',
#   'https://openalex.org/W3019334729',
#   'https://openalex.org/W3019800544',
#   'https://openalex.org/W3027187303',
#   'https://openalex.org/W3027529029',
#   'https://openalex.org/W3027864372',
#   'https://openalex.org/W3029220716',
#   'https://openalex.org/W3029504057',
#   'https://openalex.org/W3030834164',
#   'https://openalex.org/W3032648743',
#   'https://openalex.org/W3033596777',
#   'https://openalex.org/W3033805041',
#   'https://openalex.org/W3034035446',
#   'https://openalex.org/W3034614526',
#   'https://openalex.org/W3036344983',
#   'https://openalex.org/W3036603151',
#   'https://openalex.org/W3036915614',
#   'https://openalex.org/W3037253620',
#   'https://openalex.org/W3038041251',
#   'https://openalex.org/W3038089097',
#   'https://openalex.org/W3042141026',
#   'https://openalex.org/W3045818979',
#   'https://openalex.org/W3048968506',
#   'https://openalex.org/W3049244854',
#   'https://openalex.org/W3081975685',
#   'https://openalex.org/W3085465284',
#   'https://openalex.org/W3086660393',
#   'https://openalex.org/W3088192027',
#   'https://openalex.org/W3089880422',
#   'https://openalex.org/W3092511851',
#   'https://openalex.org/W3092584602',
#   'https://openalex.org/W3093230103',
#   'https://openalex.org/W3093780683',
#   'https://openalex.org/W3094243271',
#   'https://openalex.org/W3100034845',
#   'https://openalex.org/W3106738828',
#   'https://openalex.org/W3106971492',
#   'https://openalex.org/W3107344158',
#   'https://openalex.org/W3108896277',
#   'https://openalex.org/W3109403119',
#   'https://openalex.org/W3109742059',
#   'https://openalex.org/W3112058737',
#   'https://openalex.org/W3112163874',
#   'https://openalex.org/W3112391596',
#   'https://openalex.org/W3113344283',
#   'https://openalex.org/W3118531880',
#   'https://openalex.org/W3118909662',
#   'https://openalex.org/W3119701128',
#   'https://openalex.org/W3119813698',
#   'https://openalex.org/W3119985674',
#   'https://openalex.org/W3120583321',
#   'https://openalex.org/W3120626955',
#   'https://openalex.org/W3122065648',
#   'https://openalex.org/W3122324184',
#   'https://openalex.org/W3125330773',
#   'https://openalex.org/W3126029420',
#   'https://openalex.org/W3127394761',
#   'https://openalex.org/W3130544568',
#   'https://openalex.org/W3131618972',
#   'https://openalex.org/W3132024224',
#   'https://openalex.org/W3134591300',
#   'https://openalex.org/W3136673049',
#   'https://openalex.org/W3138565615',
#   'https://openalex.org/W3154641364',
#   'https://openalex.org/W3155060369',
#   'https://openalex.org/W3156374487',
#   'https://openalex.org/W3157552302',
#   'https://openalex.org/W3158211524',
#   'https://openalex.org/W3159328850',
#   'https://openalex.org/W3160268512',
#   'https://openalex.org/W3161778279',
#   'https://openalex.org/W3163559730',
#   'https://openalex.org/W3163969667',
#   'https://openalex.org/W3164061833',
#   'https://openalex.org/W3165766592',
#   'https://openalex.org/W3166418545',
#   'https://openalex.org/W3168869046',
#   'https://openalex.org/W3171242493',
#   'https://openalex.org/W3172370413',
#   'https://openalex.org/W3173925204',
#   'https://openalex.org/W3173953846',
#   'https://openalex.org/W3179857518',
#   'https://openalex.org/W3181340735',
#   'https://openalex.org/W3182015634',
#   'https://openalex.org/W3183982924',
#   'https://openalex.org/W3184541229',
#   'https://openalex.org/W3188425922',
#   'https://openalex.org/W3189444842',
#   'https://openalex.org/W3189702222',
#   'https://openalex.org/W3190979422',
#   'https://openalex.org/W3194713480',
#   'https://openalex.org/W3195843085',
#   'https://openalex.org/W3197422875',
#   'https://openalex.org/W3198853168',
#   'https://openalex.org/W3198946981',
#   'https://openalex.org/W3199431618',
#   'https://openalex.org/W3200552777',
#   'https://openalex.org/W3200928356',
#   'https://openalex.org/W3200992599',
#   'https://openalex.org/W3202239352',
#   'https://openalex.org/W3204968811',
#   'https://openalex.org/W3205401845',
#   'https://openalex.org/W3207407491',
#   'https://openalex.org/W3208135461',
#   'https://openalex.org/W3208824634',
#   'https://openalex.org/W3209354846',
#   'https://openalex.org/W3209485055',
#   'https://openalex.org/W3210020770',
#   'https://openalex.org/W3213231179',
#   'https://openalex.org/W3214384430',
#   'https://openalex.org/W3215990762',
#   'https://openalex.org/W3216480419',
#   'https://openalex.org/W4200273754',
#   'https://openalex.org/W4200478733',
#   'https://openalex.org/W4200501792',
#   'https://openalex.org/W4206526603',
#   'https://openalex.org/W4206651656',
#   'https://openalex.org/W4206737863',
#   'https://openalex.org/W4210643315',
#   'https://openalex.org/W4211096034',
#   'https://openalex.org/W4211154726',
#   'https://openalex.org/W4213091566',
#   'https://openalex.org/W4213245602',
#   'https://openalex.org/W4214529012',
#   'https://openalex.org/W4214673864',
#   'https://openalex.org/W4214737502',
#   'https://openalex.org/W4214835733',
#   'https://openalex.org/W4214855865',
#   'https://openalex.org/W4220773933',
#   'https://openalex.org/W4220929361',
#   'https://openalex.org/W4220972523',
#   'https://openalex.org/W4221011152',
#   'https://openalex.org/W4221055778',
#   'https://openalex.org/W4223463067',
#   'https://openalex.org/W4223524146',
#   'https://openalex.org/W4223547475',
#   'https://openalex.org/W4223563252',
#   'https://openalex.org/W4223971556',
#   'https://openalex.org/W4224234680',
#   'https://openalex.org/W4224318500',
#   'https://openalex.org/W4224868124',
#   'https://openalex.org/W4225004758',
#   'https://openalex.org/W4225162078',
#   'https://openalex.org/W4225246272',
#   'https://openalex.org/W4225270242',
#   'https://openalex.org/W4225567851',
#   'https://openalex.org/W4229002207',
#   'https://openalex.org/W4229011537',
#   'https://openalex.org/W4229074162',
#   'https://openalex.org/W4229363756',
#   'https://openalex.org/W4280515185',
#   'https://openalex.org/W4280535283',
#   'https://openalex.org/W4280632677',
#   'https://openalex.org/W4281397667',
#   'https://openalex.org/W4281493133',
#   'https://openalex.org/W4281756708',
#   'https://openalex.org/W4281797937',
#   'https://openalex.org/W4282022879',
#   'https://openalex.org/W4282939243',
#   'https://openalex.org/W4283319988',
#   'https://openalex.org/W4283745152',
#   'https://openalex.org/W4291020343',
#   'https://openalex.org/W4304140775',
#   'https://openalex.org/W4313531686'],
#  'related_works': ['https://openalex.org/W190336044',
#   'https://openalex.org/W1945493592',
#   'https://openalex.org/W1976273464',
#   'https://openalex.org/W2007012246',
#   'https://openalex.org/W2088880824',
#   'https://openalex.org/W2312918448',
#   'https://openalex.org/W2918803269',
#   'https://openalex.org/W3178033904',
#   'https://openalex.org/W4303685488',
#   'https://openalex.org/W4313531093'],
#  'ngrams_url': 'https://api.openalex.org/works/W4313531093/ngrams',
#  'abstract_inverted_index': {'Aging': [0],
#   'is': [1],
#   'driven': [2],
#   'by': [3, 19, 33],
#   'hallmarks': [4, 43, 74, 87],
#   'fulfilling': [5],
#   'the': [6, 15, 25, 40, 84],
#   'following': [7, 41],
#   'three': [8],
#   'premises:': [9],
#   '(1)': [10],
#   'their': [11],
#   'age-associated': [12],
#   'manifestation,': [13],
#   '(2)': [14],
#   'acceleration': [16],
#   'of': [17, 44, 53, 88, 94, 98],
#   'aging': [18, 32],
#   'experimentally': [20],
#   'accentuating': [21],
#   'them,': [22],
#   'and': [23, 71, 100],
#   '(3)': [24],
#   'opportunity': [26],
#   'to': [27, 83, 103],
#   'decelerate,': [28],
#   'stop,': [29],
#   'or': [30],
#   'reverse': [31],
#   'therapeutic': [34],
#   'interventions': [35],
#   'on': [36],
#   'them.': [37],
#   'We': [38],
#   'propose': [39],
#   'twelve': [42],
#   'aging:': [45],
#   'genomic': [46],
#   'instability,': [47],
#   'telomere': [48],
#   'attrition,': [49],
#   'epigenetic': [50],
#   'alterations,': [51],
#   'loss': [52],
#   'proteostasis,': [54],
#   'disabled': [55],
#   'macroautophagy,': [56],
#   'deregulated': [57],
#   'nutrient-sensing,': [58],
#   'mitochondrial': [59],
#   'dysfunction,': [60],
#   'cellular': [61],
#   'senescence,': [62],
#   'stem': [63],
#   'cell': [64],
#   'exhaustion,': [65],
#   'altered': [66],
#   'intercellular': [67],
#   'communication,': [68],
#   'chronic': [69],
#   'inflammation,': [70],
#   'dysbiosis.': [72],
#   'These': [73],
#   'are': [75],
#   'interconnected': [76],
#   'among': [77],
#   'each': [78],
#   'other,': [79],
#   'as': [80, 82],
#   'well': [81],
#   'recently': [85],
#   'proposed': [86],
#   'health,': [89],
#   'which': [90],
#   'include': [91],
#   'organizational': [92],
#   'features': [93],
#   'spatial': [95],
#   'compartmentalization,': [96],
#   'maintenance': [97],
#   'homeostasis,': [99],
#   'adequate': [101],
#   'responses': [102],
#   'stress.': [104]},
#  'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W4313531093',
#  'counts_by_year': [{'year': 2023, 'cited_by_count': 113},
#   {'year': 2022, 'cited_by_count': 3},
#   {'year': 2021, 'cited_by_count': 1}],
#  'updated_date': '2023-06-21T01:47:37.010141',
#  'created_date': '2023-01-06'}
